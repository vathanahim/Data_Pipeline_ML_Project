# %% [markdown]
# # DB Connection

# %%
import cassandra 
print (cassandra.__version__)
import pandas
print(pandas.__version__)
import pandas as pd
import uuid
# Out:
# 3.25.0
# 1.0.1

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
from cassandra.concurrent import execute_concurrent_with_args
# cloud_config1 = {
#         'secure_connect_bundle': '../secure-connect-capstone-project.zip'
# }
# auth_provider1 = PlainTextAuthProvider('JJvGOjuOPszNbfeoOwEinlHI', 'ZM-OR5KZAIMzqksmn01xobmZW4cNRUiIft0SnYuhW966f++ILhp+2Mq,AErDqKAF7Y0AF4ReSYLjTCgsLCqRJiL3+8uxJMoS-K6qMtM1vEmgi5IT5c62OvBJkhxBzq5T')
# cluster1 = Cluster(cloud=cloud_config1, auth_provider=auth_provider1)
# #connect to keyspace_name
# session1 = cluster1.connect('iac689')

cloud_config2= {
        'secure_connect_bundle': '../secure-connect-capstone-project2.zip'
}
auth_provider2 = PlainTextAuthProvider('OZTxZCgzatSukjKBoWpZimZs', 'cfph4pZMPt-REY_B0BTCZ-qxZfwgpIeZA2T69DIzccYlZ2I1+8gKKk6Ruk+G+70.CyFNoZymWef1Eo1KJZk,SjYbo9SgRZwY97JfG6J8uFLvNEJ8,nCjMbcGz.wgmlJC')
cluster2 = Cluster(cloud=cloud_config2, auth_provider=auth_provider2)
#connect to keyspace_name
session2 = cluster2.connect('iac689')

# %%
query = "SELECT * FROM system_schema.keyspaces;"
df = pd.DataFrame(list(session2.execute(query)))
df
# Out:
#         keyspace_name  durable_writes graph_engine        replication
# 0              iac689            True         None  [class, us-east1]
# 1         system_auth            True         None  [class, us-east1]
# 2       system_schema           False         None            [class]
# 3  data_endpoint_auth            True         None  [class, us-east1]
# 4        datastax_sla            True         None  [class, us-east1]
# 5              system           False         None            [class]
# 6       system_traces            True         None  [class, us-east1]

# %%
query = "SELECT * FROM system_schema.tables WHERE keyspace_name='iac689';"
df = pd.DataFrame(list(session2.execute(query)))
df
# Out:
#   keyspace_name table_name additional_write_policy  bloom_filter_fp_chance  \
# 0        iac689     data_2            99PERCENTILE                    0.01
# 1        iac689     kmeans            99PERCENTILE                    0.01
# 2        iac689    newdata            99PERCENTILE                    0.01
#
#                       caching   cdc comment compaction  \
# 0  [keys, rows_per_partition]  None            [class]
# 1  [keys, rows_per_partition]  None            [class]
# 2  [keys, rows_per_partition]  None            [class]
#
#                    compression  crc_check_chance  ...       flags  \
# 0  [chunk_length_in_kb, class]               1.0  ...  (compound)
# 1  [chunk_length_in_kb, class]               1.0  ...  (compound)
# 2  [chunk_length_in_kb, class]               1.0  ...  (compound)
#
#    gc_grace_seconds                                    id max_index_interval  \
# 0            864000  a68727d0-7f1c-11ec-bb17-45ae5e7b1bda               2048
# 1            864000  95ef9290-8944-11ec-bb17-45ae5e7b1bda               2048
# 2            864000  3571f450-8dcf-11ec-a016-ef0b22327c1e               2048
#
#    memtable_flush_period_in_ms min_index_interval  nodesync  read_repair  \
# 0                            0                128      None     BLOCKING
# 1                            0                128      None     BLOCKING
# 2                            0                128      None     BLOCKING
#
#    read_repair_chance speculative_retry
# 0                 0.0      99PERCENTILE
# 1                 0.0      99PERCENTILE
# 2                 0.0      99PERCENTILE
#
# [3 rows x 23 columns]

# %%
query = "SELECT * FROM system_schema.columns WHERE keyspace_name='iac689' and table_name = 'data_1';"
df = pd.DataFrame(list(session2.execute(query)))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # DB_Insert

# %%
import pandas as pd
import glob

# %%
path_list = glob.glob('../../cap_data2/*.csv')
df_list = []
for i in path_list:
    df_list.append(pd.read_csv(i))
# Out:
# /Users/vathanahim/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in range(len(df_list)):
    if (i < 5):
        df_list[i]['time'] = pd.to_datetime(df_list[i]['time']).dt.date
        df_list[i]['truck_name'] = df_list[i]['truck_name'].str.replace(r"[a-zA-Z|-]","")
        df_list[i]['truck_name'] = 'abc-'+df_list[i]['truck_id'].astype(str)
    else:
        df_list[i]['start_time'] = pd.to_datetime(df_list[i]['start_time']).dt.date
        df_list[i]['truck_name'] = df_list[i]['truck_name'].str.replace(r"[a-zA-Z|-]","")
        df_list[i]['truck_name'] = 'abc-'+df_list[i]['truck_id'].astype(str)

# %%
#Insert for the last dataframe into a different table (kind of slow)
# query = "INSERT INTO data_1 (uid, active, reading_id, start_mileage, start_time, truck_id, truck_name, type) VALUES (?,?,?,?,?,?,?,?)"
# prepared = session1.prepare(query)
# for i in df.itertuples():
#     print(i.truck_id)
#     session1.execute(prepared, (uuid.uuid1(), i.active, i.reading_id, i.start_mileage, i.start_time, i.truck_id, i.truck_name, i.not_active))

# %%
df_engine_speed = df_list[0].copy()
df_altitude = df_list[1].copy().dropna()
df_inclination = df_list[2].copy()
df_wheel_based_speed = pd.concat([df_list[3],df_list[4]])

# %%
inclination_hist = [-20, -18,-15,-13, -11.5,-10.5,-9.5,-8.5,-7.5,-6.5,-5.5,-4.5,-3.5,-2.5,-1.5,-0.5,0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5,9.5,10.5,11.5,13.0,15.0,18.0,20.0]
altitude_hist = [i for i in range(500, 7000, 500)]
vehicle_speed_hist = [0,5,12,19,26,33,40,46,53,60,68,75,82,89,96,103,110,116,123,130]
engine_speed_hist = [i for i in range(0,12500, 500)]

# %%
def helper(df, bin_val:list):
#     df= df.pivot_table(index=['time', 'truck_id','type'], columns='bin_num',
#                      values='value').reset_index()
    df = df[df.bin_num !='start_mileage']
    num = len(df['bin_num'].unique())
    bin_val = bin_val[:num]
    print(len(bin_val),num)
    new_val = []
    for i in df['bin_num']:
        n = int(i.split('_')[-1])
        new_val.append(bin_val[n])
    df['new_val'] = new_val
    df['final_val'] = (df['value']*df['new_val'])/375
    return df

# %%
df_engine_speed = helper(df_engine_speed, engine_speed_hist)
df_inclination = helper(df_inclination, inclination_hist)
df_wheel_based_speed = helper(df_wheel_based_speed, vehicle_speed_hist)
# Out:
# 24 24
# /Users/vathanahim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/vathanahim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 31 31
# 19 19

# %%
df_altitude = df_altitude.rename(columns={'value':'final_val'})
df_altitude
# Out:
#              time truck_name  truck_id  \
# 0      2021-11-17    abc-242       242
# 1      2021-11-17    abc-242       242
# 2      2021-11-17    abc-242       242
# 3      2021-11-17    abc-242       242
# 4      2021-01-04    abc-294       294
# ...           ...        ...       ...
# 95467  2021-02-15    abc-277       277
# 95468  2021-02-17    abc-277       277
# 95469  2021-02-17    abc-277       277
# 95470  2021-02-17    abc-277       277
# 95471  2021-02-17    abc-277       277
#
#                                          type  reading_id bin_num  final_val
# 0          Time(hours) at different Altitudes       86021   col_0   0.000000
# 1      Distance(miles) at different Altitudes       86021   col_0   0.000000
# 2          Time(hours) at different Altitudes       86021   col_0   0.000000
# 3      Distance(miles) at different Altitudes       86021   col_0   0.000000
# 4          Time(hours) at different Altitudes       86022   col_0   0.772778
# ...                                       ...         ...     ...        ...
# 95467  Distance(miles) at different Altitudes      130151   col_0   0.000000
# 95468      Time(hours) at different Altitudes      130152   col_0   0.000000
# 95469  Distance(miles) at different Altitudes      130152   col_0   0.000000
# 95470      Time(hours) at different Altitudes      130152   col_0   0.000000
# 95471  Distance(miles) at different Altitudes      130152   col_0   0.000000
#
# [95472 rows x 7 columns]

# %%
df_list = [df_engine_speed, df_altitude, df_inclination, df_wheel_based_speed]
df = pd.concat(df_list)

# %%
df = df.pivot_table(index=['time', 'truck_id'], columns='type',
                     values='final_val',aggfunc='mean').reset_index()
df.columns
# Out:
# Index(['time', 'truck_id', 'Distance(miles) at WheelBasedVehicleSpeed(mph)',
#        'Distance(miles) at different Altitudes',
#        'Distance(miles) at different Engine Speeds (rpms)',
#        'Distance(miles) at different RoadInclination(%)',
#        'Time(hours) at WheelBasedVehicleSpeed(mph)',
#        'Time(hours) at different Altitudes',
#        'Time(hours) at different Engine Speeds (rpms)',
#        'Time(hours) at different RoadInclination(%)'],
#       dtype='object', name='type')

# %%
df.describe()
# Out:
# type      truck_id  Distance(miles) at WheelBasedVehicleSpeed(mph)  \
# count  4547.000000                                    4.547000e+03
# mean    258.192435                                    1.574406e+03
# std      35.043084                                    1.344223e+05
# min     201.000000                                   -3.923807e+06
# 25%     221.000000                                    1.028924e+02
# 50%     274.000000                                    6.309158e+02
# 75%     290.000000                                    1.587130e+03
# max     297.000000                                    6.096331e+06
#
# type   Distance(miles) at different Altitudes  \
# count                            3.543000e+03
# mean                             6.644728e+05
# std                              9.948156e+05
# min                              0.000000e+00
# 25%                              1.080975e+02
# 50%                              2.793622e+05
# 75%                              9.243595e+05
# max                              1.674670e+07
#
# type   Distance(miles) at different Engine Speeds (rpms)  \
# count                                       4.546000e+03
# mean                                       -2.687061e+04
# std                                         4.913955e+06
# min                                        -2.021381e+08
# 25%                                         1.920728e+03
# 50%                                         7.751597e+03
# 75%                                         1.799504e+04
# max                                         2.001405e+08
#
# type   Distance(miles) at different RoadInclination(%)  \
# count                                      3697.000000
# mean                                        241.140990
# std                                       36329.453351
# min                                     -969514.812394
# 25%                                           1.679262
# 50%                                           7.765962
# 75%                                          16.912249
# max                                      923215.617181
#
# type   Time(hours) at WheelBasedVehicleSpeed(mph)  \
# count                                 4547.000000
# mean                                     0.014902
# std                                      0.014190
# min                                      0.000005
# 25%                                      0.003519
# 50%                                      0.010526
# 75%                                      0.023346
# max                                      0.243043
#
# type   Time(hours) at different Altitudes  \
# count                         3543.000000
# mean                             1.133195
# std                              1.353892
# min                              0.000000
# 25%                              0.021667
# 50%                              0.612253
# 75%                              1.915750
# max                             13.541700
#
# type   Time(hours) at different Engine Speeds (rpms)  \
# count                                    4546.000000
# mean                                        0.165476
# std                                         0.162890
# min                                         0.000000
# 25%                                         0.042518
# 50%                                         0.117432
# 75%                                         0.264072
# max                                         2.556465
#
# type   Time(hours) at different RoadInclination(%)
# count                                  3697.000000
# mean                                      0.000120
# std                                       0.000142
# min                                      -0.000749
# 25%                                       0.000018
# 50%                                       0.000087
# 75%                                       0.000185
# max                                       0.001630

# %%
df['uuid'] = df.index.to_series().map(lambda x: uuid.uuid4())
df
# Out:
# type        time  truck_id  Distance(miles) at WheelBasedVehicleSpeed(mph)  \
# 0     2020-12-28       286                                    -5061.639619
# 1     2020-12-29       286                                    -4821.534286
# 2     2020-12-30       286                                    -4267.162667
# 3     2020-12-31       286                                    -4392.197333
# 4     2021-01-01       207                                        0.000000
# ...          ...       ...                                             ...
# 4542  2022-01-08       294                                      163.061968
# 4543  2022-01-08       296                                      835.929810
# 4544  2022-01-09       208                                     2345.843048
# 4545  2022-01-09       209                                        0.000000
# 4546  2022-01-09       296                                      881.148709
#
# type  Distance(miles) at different Altitudes  \
# 0                              162463.500000
# 1                              144921.500000
# 2                              119689.500000
# 3                              148580.433333
# 4                                   0.000000
# ...                                      ...
# 4542                           599411.000000
# 4543                                0.000000
# 4544                                     NaN
# 4545                           135474.000000
# 4546                                0.000000
#
# type  Distance(miles) at different Engine Speeds (rpms)  \
# 0                                           1653.888889
# 1                                           2911.944444
# 2                                            481.388889
# 3                                           -218.518519
# 4                                              0.000000
# ...                                                 ...
# 4542                                        6301.111111
# 4543                                        9827.086667
# 4544                                       22161.355556
# 4545                                           0.000000
# 4546                                        8892.261111
#
# type  Distance(miles) at different RoadInclination(%)  \
# 0                                            3.570968
# 1                                           -2.104731
# 2                                            1.567599
# 3                                            3.659283
# 4                                            0.000000
# ...                                               ...
# 4542                                              NaN
# 4543                                        10.526150
# 4544                                        42.738090
# 4545                                         0.000000
# 4546                                        14.322758
#
# type  Time(hours) at WheelBasedVehicleSpeed(mph)  \
# 0                                       0.004781
# 1                                       0.004836
# 2                                       0.003690
# 3                                       0.003858
# 4                                       0.008085
# ...                                          ...
# 4542                                    0.005615
# 4543                                    0.010956
# 4544                                    0.027719
# 4545                                    0.001070
# 4546                                    0.009720
#
# type  Time(hours) at different Altitudes  \
# 0                               1.815138
# 1                               1.781807
# 2                               1.565835
# 3                               1.470555
# 4                               0.001250
# ...                                  ...
# 4542                            0.858795
# 4543                            0.000000
# 4544                                 NaN
# 4545                            0.255278
# 4546                            0.000000
#
# type  Time(hours) at different Engine Speeds (rpms)  \
# 0                                          0.126752
# 1                                          0.129668
# 2                                          0.108133
# 3                                          0.099429
# 4                                          0.111227
# ...                                             ...
# 4542                                       0.121662
# 4543                                       0.142176
# 4544                                       0.290380
# 4545                                       0.014722
# 4546                                       0.108522
#
# type  Time(hours) at different RoadInclination(%)  \
# 0                                    4.898696e-07
# 1                                   -7.341613e-06
# 2                                    6.798120e-06
# 3                                    6.845851e-06
# 4                                   -5.153527e-05
# ...                                           ...
# 4542                                          NaN
# 4543                                 1.336201e-04
# 4544                                 8.251616e-04
# 4545                                 7.978495e-05
# 4546                                 1.675436e-04
#
# type                                  uuid
# 0     74cd8746-0b55-4acb-8fa0-8b994a100c08
# 1     27dd16d1-0f5f-44a8-b154-7bf066e94f41
# 2     3f92ee1f-d2f5-43e6-949e-3eaa6196952d
# 3     5c64b43b-8d41-45a2-acba-ee8323afe22e
# 4     482ab6fc-daaa-4d55-b6ae-822c9c662f89
# ...                                    ...
# 4542  8044d20c-34e3-49e1-9fd1-2d39c217689e
# 4543  eb34694e-5eb3-47a7-aeaa-93702d1d4f0d
# 4544  006fffbe-be2b-4981-b03a-ae63b8588658
# 4545  1eaa153b-8219-46e0-8019-6656e050e112
# 4546  18fe391d-9774-4c78-ba7e-4a58d91a98b0
#
# [4547 rows x 11 columns]

# %%
df.describe()
# Out:
# type      truck_id  Distance(miles) at WheelBasedVehicleSpeed(mph)  \
# count  4547.000000                                    4.547000e+03
# mean    258.192435                                    1.574406e+03
# std      35.043084                                    1.344223e+05
# min     201.000000                                   -3.923807e+06
# 25%     221.000000                                    1.028924e+02
# 50%     274.000000                                    6.309158e+02
# 75%     290.000000                                    1.587130e+03
# max     297.000000                                    6.096331e+06
#
# type   Distance(miles) at different Altitudes  \
# count                            3.543000e+03
# mean                             6.644728e+05
# std                              9.948156e+05
# min                              0.000000e+00
# 25%                              1.080975e+02
# 50%                              2.793622e+05
# 75%                              9.243595e+05
# max                              1.674670e+07
#
# type   Distance(miles) at different Engine Speeds (rpms)  \
# count                                       4.546000e+03
# mean                                       -2.687061e+04
# std                                         4.913955e+06
# min                                        -2.021381e+08
# 25%                                         1.920728e+03
# 50%                                         7.751597e+03
# 75%                                         1.799504e+04
# max                                         2.001405e+08
#
# type   Distance(miles) at different RoadInclination(%)  \
# count                                      3697.000000
# mean                                        241.140990
# std                                       36329.453351
# min                                     -969514.812394
# 25%                                           1.679262
# 50%                                           7.765962
# 75%                                          16.912249
# max                                      923215.617181
#
# type   Time(hours) at WheelBasedVehicleSpeed(mph)  \
# count                                 4547.000000
# mean                                     0.014902
# std                                      0.014190
# min                                      0.000005
# 25%                                      0.003519
# 50%                                      0.010526
# 75%                                      0.023346
# max                                      0.243043
#
# type   Time(hours) at different Altitudes  \
# count                         3543.000000
# mean                             1.133195
# std                              1.353892
# min                              0.000000
# 25%                              0.021667
# 50%                              0.612253
# 75%                              1.915750
# max                             13.541700
#
# type   Time(hours) at different Engine Speeds (rpms)  \
# count                                    4546.000000
# mean                                        0.165476
# std                                         0.162890
# min                                         0.000000
# 25%                                         0.042518
# 50%                                         0.117432
# 75%                                         0.264072
# max                                         2.556465
#
# type   Time(hours) at different RoadInclination(%)
# count                                  3697.000000
# mean                                      0.000120
# std                                       0.000142
# min                                      -0.000749
# 25%                                       0.000018
# 50%                                       0.000087
# 75%                                       0.000185
# max                                       0.001630

# %%
df['Distance(miles) at WheelBasedVehicleSpeed(mph)'] = abs(df['Distance(miles) at WheelBasedVehicleSpeed(mph)'])
df['Distance(miles) at different Engine Speeds (rpms)'] = abs(df['Distance(miles) at different Engine Speeds (rpms)'])
df['Time(hours) at different Engine Speeds (rpms)']= abs((df['Time(hours) at different Engine Speeds (rpms)']-df['Time(hours) at different Engine Speeds (rpms)'].min())/(df['Time(hours) at different Engine Speeds (rpms)'].max()-df['Time(hours) at different Engine Speeds (rpms)'].min()))
df['Time(hours) at different RoadInclination(%)'] = abs(df['Time(hours) at different RoadInclination(%)'])

# %%
l = []
for i in df[['uuid','time','Distance(miles) at different Altitudes','Distance(miles) at different Engine Speeds (rpms)','Distance(miles) at different RoadInclination(%)', 'Distance(miles) at WheelBasedVehicleSpeed(mph)','Time(hours) at different Altitudes', 'Time(hours) at different Engine Speeds (rpms)','Time(hours) at different RoadInclination(%)','Time(hours) at WheelBasedVehicleSpeed(mph)','truck_id']].columns:
    l.append(df[i].tolist())

# %%
query = """insert into test_1 (ui , datel , distance_at_diff_altitude , distance_at_diff_engine_speeds , distance_at_diff_roadinclination , distance_at_wheelbased_vehicle_speed , time_at_diff_altitude , time_at_diff_engine_speeds , time_at_diff_roadinclination , time_at_wheelbased_vehicle_speed , truck_id)
values (?,?,?,?,?,?,?,?,?,?,?);"""
prepared = session2.prepare(query)
execute_concurrent_with_args(session2, prepared, zip(l[0],l[1],l[2],l[3],l[4],l[5],l[6],l[7],l[8],l[9],l[10]))
# Out:
# [ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f971903d250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d6290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e82b250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d5950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f971903db50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f971903dd50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e827950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719036490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2e0b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2e0dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d5290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d5710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97190366d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a3290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f971903d490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f971903dfd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719036250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d6050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d6750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d6510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719046910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719046fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860c9f710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97190466d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719046450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860c9f950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719046250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca74d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719046d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acb64d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca7dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860c9fb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d5510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e82b910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815bc710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acaf950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815bc2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d6990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca7710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca7b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d5050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e834910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d6c10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d5dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acaf050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a3090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e82bb50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acb6b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e827090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acaf4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e834d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e8274d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719046b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca7290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d6dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e834fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2e0950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98df2d5b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acaf710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acafbd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acafdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719036d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e82bd90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca7990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719036910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719036b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e82b690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acaf290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860c9fdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815bcb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e54050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e54290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e827b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e8346d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e827dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e54710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e544d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e5a710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e834450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca0050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e82b490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e5a950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e834250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e827290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9719036fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e834b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e5abd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e54990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e827750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f973e82bfd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815bc4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f971903d6d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca7050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f971903d8d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815d6e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e54b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e5add0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e43050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e434d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e432d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a34d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acb6090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a3b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acb6dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acb6950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903c04d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acb6750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985acb6290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903afb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a3710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca0950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e4cdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e4c290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a9290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815bc950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e5a4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e4c4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e4c950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca0290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903c0dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e5a050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca0dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a9710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e5a2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815c1050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903af710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca0510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a9050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca0710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e4c710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e54dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903af050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f985aca0b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e4c050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e4cbd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a3dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb6b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b052dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e43710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb04d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e43990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb6050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903c0750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e43b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb64d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb6950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903afdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a9b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb6710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb0050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb0290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb0710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb0950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860c9f2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815e9050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb0b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb0dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a94d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860ca94d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860ca9090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815bcdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860ca9290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb6e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903af950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a9dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860ca9e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860c9f050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9739e43dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a3950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903af290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860cb6290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903af4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903ba950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903ba2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903ba4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860ca9710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860ca9b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860ca9990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9860c9f4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903c0290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903ba710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815cc290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903c0950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903bab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815bc050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903badd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903ba050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903a9950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903c0b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98903c0090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815c1950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815d6990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b059510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815cc050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b059710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815d6b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b059290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815c1e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815c1710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815c1b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815c14d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815c1290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815e9710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815e9b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b052710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815d6050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815d6290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b059050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b059b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815d6510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815e9950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815ccdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b052990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815e9e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b050050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815e9290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815e94d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b059950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815cc710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815cc950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b052b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b059dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b0524d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b068510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b052090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b068290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b052290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d1593e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b0502d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b068050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815cc4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b050dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b050710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815ccb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b0504d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b050990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b050b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98815d6710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b068710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b061050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95de690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b068dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b068b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b061510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b0612d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b061750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95de490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95eed50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b068950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b061950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95eeb50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95deb50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d1593950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ee910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc86050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95e5fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95e56d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95e5b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95e5910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95e5250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b061bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f978b061dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95e5490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95def90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ee6d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ded90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95de910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ee250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d0b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ee450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d1593710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95e5d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d76d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d0910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d1593b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d7b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95eefd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95de250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d7f90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d7910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d7d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d0690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15c7b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d0490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15c7710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15badd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15c7dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15ba050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15b1290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d7250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ec050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15b14d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15ba290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15bab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15b1710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15b1b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15ba4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15ba950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15b1990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15ba750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15b1050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15c72d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15c7950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ec290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d0d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d0f90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d0250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ec4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ec710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc7c4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ecb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc86290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ecdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95d7490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc7c710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15c7050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d1593290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc7c950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc7cb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15c74d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d95ec950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15934d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d15b1dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98d1593090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc7cdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc86710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc7c290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc702d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc70710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc86950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc864d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc86b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc86e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc70050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc704d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc7c050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc70b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc70990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc664d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc66b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc66710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc66290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc66950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc70dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc66090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8918490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc66dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8918b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc5edd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8918250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc5e050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d89108d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8910d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8910450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8910fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8910250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d89106d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d89188d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc5e2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc5e4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d89186d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc5e950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc5e710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc5eb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8918fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8918d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8910b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d88fb8d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8902250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6217dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d88fb490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6217050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d88fb250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d890d4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d88fbf90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d88fb6d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e62174d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e62172d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d890d950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d88fbd90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8902910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8902b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d89026d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8902450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8902d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6217bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6208450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d890db90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6208910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6217750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6210690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d890de10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d8902fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d890d290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6210490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d890d710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6210910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6201b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d890d050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6210b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6210d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6217950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97d88fbb50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e62086d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6208250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6210f90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6201910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6210210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6208fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61fab10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6208b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd88a090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6208d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61fad90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61f1490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61fa910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6201f90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6201d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61f1250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd88a290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd88ab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61f1d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61fa6d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6201490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61f1fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd88a990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61fa450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd88a710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e62016d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e6201250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd88a4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61faf90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd882290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61fa250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61f1b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bd074d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd88ae10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcfe990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd882050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61f16d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bd07750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bd07950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97e61f18d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd882990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd86c290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd882710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd882dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd87c290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd87c4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd87c750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd87c950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd882b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd876950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd86c050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd87c050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcfe4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd87cb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd87cdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd876b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd876510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd86c510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd876290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd876050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd86c710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd876710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd882510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd876e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bd07b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcfe050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98cd866510>),
# ...
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf88950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf88750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf88050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892bad490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892bad250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf89710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba6d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf89050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba6fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf88dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf88290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf892d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc9bb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf89b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bca1950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf88b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf75090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf75290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf894d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf89950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bca1b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba4290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba4710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf75dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba44d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba4950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba4b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf75510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf6f290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf75950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba4050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf75710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9892ba4dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf75b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf6f090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf6f4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf60290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf55510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf55710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf6f710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf60050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf55950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492db50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492df90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492d910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf55dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492d250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf60710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492d490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf55290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc9b050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf6f950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492d690>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf6fe10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf60dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc9b710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf60b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492dd90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc0750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf6fb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98c9649050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97449086d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492c050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744901b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744901490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744901250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcb1290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcaab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf60950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcba290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf55090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492c2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcd4290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf604d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98ccf55b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc9050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc9990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc9710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744908250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492c4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcba050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492cb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974491efd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492ce10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744901910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492c950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974492c710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcba750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc9b290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974491ed90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744919fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcb1750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974491e8d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bca1290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974491eb50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744919b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974491e6d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcd4dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bca1dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc94d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc0950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcba4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744919490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974491e250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744901fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744919910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744908910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97449016d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744911f90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcba950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcd44d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f974491e490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744919d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97449196d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcb14d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcaadd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcd4710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc0290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcd4950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc9b950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc0090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744911d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744919250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc9b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc9290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744911490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744908d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744911250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744901d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f97449116d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744908b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744908490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bc9b4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f9744908fd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcd4050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcd4b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcb1950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc9dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc0bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bca1090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcaa050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc04d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcc0dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98c9649dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98c963e710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcbae10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98c963eb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcaa290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcbab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98c963e950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcaa4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98c9637290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcaa750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98c9649290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f98c9649710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f986bcaa950>),
#  ...]

# %%
query = "select * from iac689.data_1;"
df = pd.DataFrame(list(session1.execute(query)))
df
# Out:
#                                        uid        active  reading_id  \
# 0     1b644c6e-7f03-11ec-99b7-acde48001122   5400.000000      103995
# 1     1ba064e2-7f03-11ec-99b7-acde48001122   7340.000000      103997
# 2     d847cb7c-7f02-11ec-99b7-acde48001122  11815.000000      103358
# 3     6a9d1424-7f02-11ec-99b7-acde48001122      0.021667       99698
# 4     f6d2f940-7f02-11ec-99b7-acde48001122      0.138056      103646
# ...                                    ...           ...         ...
# 8525  eb7bfd62-7f02-11ec-99b7-acde48001122      0.000000      103539
# 8526  fe85cb18-7f02-11ec-99b7-acde48001122      0.115278      103720
# 8527  17da6c18-7f03-11ec-99b7-acde48001122      0.254722      103961
# 8528  5300048e-7f02-11ec-99b7-acde48001122      0.130556       86044
# 8529  239fc9da-7f03-11ec-99b7-acde48001122      0.356944      104072
#
#       start_mileage  start_time  truck_id truck_name  \
# 0        15906600.0  2021-02-19       205    abc-205
# 1        15912000.0  2021-02-19       205    abc-205
# 2        12433600.0  2021-01-13       205    abc-205
# 3        17789500.0  2021-01-11       284    abc-284
# 4        14102000.0  2021-02-01       205    abc-205
# ...             ...         ...       ...        ...
# 8525     13469200.0  2021-01-25       205    abc-205
# 8526     14719100.0  2021-02-05       205    abc-205
# 8527     15560800.0  2021-02-16       205    abc-205
# 8528      8068540.0  2021-02-15       294    abc-294
# 8529     16133600.0  2021-02-23       205    abc-205
#
#                                 type
# 0     Distance(miles) with CC active
# 1     Distance(miles) with CC active
# 2     Distance(miles) with CC active
# 3         Time(hours) with CC Active
# 4         Time(hours) with CC Active
# ...                              ...
# 8525  Distance(miles) with CC active
# 8526      Time(hours) with CC Active
# 8527      Time(hours) with CC Active
# 8528      Time(hours) with CC Active
# 8529      Time(hours) with CC Active
#
# [8530 rows x 8 columns]

# %%
query = "select * from iac689.data_2;"
df = pd.DataFrame(list(session2.execute(query)))
df
# Out:
#                                         ui       datel  \
# 0     1c9a40f7-28bd-448b-837f-7e6f26867cee  2021-01-12
# 1     eed85ca4-db7c-42a3-b4f6-46660ac6f5ab  2021-10-01
# 2     69b49f87-6525-4203-8168-a406da377443  2021-11-18
# 3     375516c0-521f-4411-b83a-74f84ab454be  2021-05-12
# 4     3f15f13f-62e0-435a-910b-317c3fda47ac  2021-01-25
# ...                                    ...         ...
# 4542  2d46a503-3581-40eb-9ad9-124e7a362185  2021-07-27
# 4543  9932ae23-5a33-42f1-9a87-ec803a18c325  2021-08-06
# 4544  c0b4c700-96ab-438e-a272-e45ba97a3974  2021-06-03
# 4545  e29ed179-f997-429f-b592-8158bd7b2030  2021-10-11
# 4546  06d041b4-eef0-4474-ae48-7b80d50ec25d  2021-04-08
#
#       distance_at_diff_altitude  distance_at_diff_engine_speeds  \
# 0                  2.468247e+05                    7.139896e+05
# 1                  0.000000e+00                    1.087964e+07
# 2                           NaN                    1.010224e+07
# 3                  5.921890e+05                    5.071094e+05
# 4                           NaN                    2.643425e+07
# ...                         ...                             ...
# 4542               5.230573e+05                    8.439053e+05
# 4543               8.052310e+05                    8.942562e+05
# 4544               2.373810e+06                    2.268493e+05
# 4545                        NaN                    5.238979e+06
# 4546                        NaN                    5.120176e+06
#
#       distance_at_diff_roadinclination  distance_at_wheelbased_vehicle_speed  \
# 0                         5.578044e+05                          9.648508e+05
# 1                         8.499720e+06                          1.470222e+07
# 2                         7.892374e+06                          1.365167e+07
# 3                                  NaN                          6.852830e+05
# 4                         2.065176e+07                          3.572196e+07
# ...                                ...                                   ...
# 4542                               NaN                          1.140412e+06
# 4543                               NaN                          1.208454e+06
# 4544                               NaN                          3.065532e+05
# 4545                      4.092952e+06                          7.079684e+06
# 4546                      4.000138e+06                          6.919157e+06
#
#       time_at_diff_altitude  time_at_diff_engine_speeds  \
# 0                  0.318268                7.137108e+05
# 1                  0.000000                1.087643e+07
# 2                       NaN                1.010193e+07
# 3                  1.227917                5.051501e+05
# 4                       NaN                2.643222e+07
# ...                     ...                         ...
# 4542               0.531806                8.434997e+05
# 4543               4.340280                8.896362e+05
# 4544               2.066203                2.259348e+05
# 4545                    NaN                5.232000e+06
# 4546                    NaN                5.112247e+06
#
#       time_at_diff_roadinclination  time_at_wheelbased_vehicle_speed  truck_id
# 0                     5.575866e+05                      9.644741e+05       284
# 1                     8.497214e+06                      1.469788e+07       296
# 2                     7.892130e+06                      1.365125e+07       282
# 3                              NaN                      6.826352e+05       294
# 4                     2.065017e+07                      3.571922e+07       279
# ...                            ...                               ...       ...
# 4542                           NaN                      1.139864e+06       205
# 4543                           NaN                      1.202211e+06       294
# 4544                           NaN                      3.053172e+05       292
# 4545                  4.087500e+06                      7.070270e+06       208
# 4546                  3.993943e+06                      6.908442e+06       277
#
# [4547 rows x 11 columns]

# %% [markdown]
# (ui uuid primary key, datel date, distance_at_diff_altitude float, distance_at_diff_engine_speeds float, distance_at_diff_roadinclination float, distance_at_wheelbased_vehicle_speed float, time_at_diff_altitude float, time_at_diff_engine_speeds float, time_at_diff_roadinclination float, time_at_wheelbased_vehicle_speed float, truck_id int)
