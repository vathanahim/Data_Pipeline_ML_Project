# %% [markdown]
# # DB Connection

# %%
import cassandra 
print (cassandra.__version__)
import pandas
print(pandas.__version__)
import pandas as pd
import uuid
# Out:
# 3.25.0
# 1.0.1

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
from cassandra.concurrent import execute_concurrent_with_args
# cloud_config1 = {
#         'secure_connect_bundle': '../secure-connect-capstone-project.zip'
# }
# auth_provider1 = PlainTextAuthProvider('JJvGOjuOPszNbfeoOwEinlHI', 'ZM-OR5KZAIMzqksmn01xobmZW4cNRUiIft0SnYuhW966f++ILhp+2Mq,AErDqKAF7Y0AF4ReSYLjTCgsLCqRJiL3+8uxJMoS-K6qMtM1vEmgi5IT5c62OvBJkhxBzq5T')
# cluster1 = Cluster(cloud=cloud_config1, auth_provider=auth_provider1)
# #connect to keyspace_name
# session1 = cluster1.connect('iac689')

cloud_config2= {
        'secure_connect_bundle': '../secure-connect-capstone-project2.zip'
}
auth_provider2 = PlainTextAuthProvider('OZTxZCgzatSukjKBoWpZimZs', 'cfph4pZMPt-REY_B0BTCZ-qxZfwgpIeZA2T69DIzccYlZ2I1+8gKKk6Ruk+G+70.CyFNoZymWef1Eo1KJZk,SjYbo9SgRZwY97JfG6J8uFLvNEJ8,nCjMbcGz.wgmlJC')
cluster2 = Cluster(cloud=cloud_config2, auth_provider=auth_provider2)
#connect to keyspace_name
session2 = cluster2.connect('iac689')

# %%
query = "SELECT * FROM system_schema.keyspaces;"
df = pd.DataFrame(list(session2.execute(query)))
df
# Out:
#         keyspace_name  durable_writes graph_engine        replication
# 0              iac689            True         None  [class, us-east1]
# 1         system_auth            True         None  [class, us-east1]
# 2       system_schema           False         None            [class]
# 3  data_endpoint_auth            True         None  [class, us-east1]
# 4        datastax_sla            True         None  [class, us-east1]
# 5              system           False         None            [class]
# 6       system_traces            True         None  [class, us-east1]

# %%
query = "SELECT * FROM system_schema.tables WHERE keyspace_name='iac689';"
df = pd.DataFrame(list(session2.execute(query)))
df
# Out:
#   keyspace_name table_name additional_write_policy  bloom_filter_fp_chance  \
# 0        iac689     data_2            99PERCENTILE                    0.01
# 1        iac689     kmeans            99PERCENTILE                    0.01
# 2        iac689    newdata            99PERCENTILE                    0.01
#
#                       caching   cdc comment compaction  \
# 0  [keys, rows_per_partition]  None            [class]
# 1  [keys, rows_per_partition]  None            [class]
# 2  [keys, rows_per_partition]  None            [class]
#
#                    compression  crc_check_chance  ...       flags  \
# 0  [chunk_length_in_kb, class]               1.0  ...  (compound)
# 1  [chunk_length_in_kb, class]               1.0  ...  (compound)
# 2  [chunk_length_in_kb, class]               1.0  ...  (compound)
#
#    gc_grace_seconds                                    id max_index_interval  \
# 0            864000  a68727d0-7f1c-11ec-bb17-45ae5e7b1bda               2048
# 1            864000  95ef9290-8944-11ec-bb17-45ae5e7b1bda               2048
# 2            864000  3571f450-8dcf-11ec-a016-ef0b22327c1e               2048
#
#    memtable_flush_period_in_ms min_index_interval  nodesync  read_repair  \
# 0                            0                128      None     BLOCKING
# 1                            0                128      None     BLOCKING
# 2                            0                128      None     BLOCKING
#
#    read_repair_chance speculative_retry
# 0                 0.0      99PERCENTILE
# 1                 0.0      99PERCENTILE
# 2                 0.0      99PERCENTILE
#
# [3 rows x 23 columns]

# %%
query = "SELECT * FROM system_schema.columns WHERE keyspace_name='iac689' and table_name = 'data_1';"
df = pd.DataFrame(list(session2.execute(query)))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # DB_Insert

# %%
import pandas as pd
import glob

# %%
path_list = glob.glob('../../cap_data2/*.csv')
df_list = []
for i in path_list:
    df_list.append(pd.read_csv(i))
# Out:
# /Users/vathanahim/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for i in range(len(df_list)):
    if (i < 5):
        df_list[i]['time'] = pd.to_datetime(df_list[i]['time']).dt.date
        df_list[i]['truck_name'] = df_list[i]['truck_name'].str.replace(r"[a-zA-Z|-]","")
        df_list[i]['truck_name'] = 'abc-'+df_list[i]['truck_id'].astype(str)
    else:
        df_list[i]['start_time'] = pd.to_datetime(df_list[i]['start_time']).dt.date
        df_list[i]['truck_name'] = df_list[i]['truck_name'].str.replace(r"[a-zA-Z|-]","")
        df_list[i]['truck_name'] = 'abc-'+df_list[i]['truck_id'].astype(str)

# %%
#Insert for the last dataframe into a different table (kind of slow)
# query = "INSERT INTO data_1 (uid, active, reading_id, start_mileage, start_time, truck_id, truck_name, type) VALUES (?,?,?,?,?,?,?,?)"
# prepared = session1.prepare(query)
# for i in df.itertuples():
#     print(i.truck_id)
#     session1.execute(prepared, (uuid.uuid1(), i.active, i.reading_id, i.start_mileage, i.start_time, i.truck_id, i.truck_name, i.not_active))

# %%
df_engine_speed = df_list[0].copy()
df_altitude = df_list[1].copy().dropna()
df_inclination = df_list[2].copy()
df_wheel_based_speed = pd.concat([df_list[3],df_list[4]])

# %%
inclination_hist = [-20, -18,-15,-13, -11.5,-10.5,-9.5,-8.5,-7.5,-6.5,-5.5,-4.5,-3.5,-2.5,-1.5,-0.5,0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5,8.5,9.5,10.5,11.5,13.0,15.0,18.0,20.0]
altitude_hist = [i for i in range(500, 7000, 500)]
vehicle_speed_hist = [0,5,12,19,26,33,40,46,53,60,68,75,82,89,96,103,110,116,123,130]
engine_speed_hist = [i for i in range(0,12500, 500)]

# %%
def helper(df, bin_val:list):
#     df= df.pivot_table(index=['time', 'truck_id','type'], columns='bin_num',
#                      values='value').reset_index()
    df = df[df.bin_num !='start_mileage']
    num = len(df['bin_num'].unique())
    bin_val = bin_val[:num]
    print(len(bin_val),num)
    new_val = []
    for i in df['bin_num']:
        n = int(i.split('_')[-1])
        new_val.append(bin_val[n])
    df['new_val'] = new_val
    df['final_val'] = (df['value']*df['new_val'])
    return df

# %%
df_engine_speed = helper(df_engine_speed, engine_speed_hist)
df_inclination = helper(df_inclination, inclination_hist)
df_wheel_based_speed = helper(df_wheel_based_speed, vehicle_speed_hist)
# Out:
# 24 24
# /Users/vathanahim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/vathanahim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 31 31
# 19 19

# %%
df_altitude = df_altitude.rename(columns={'value':'final_val'})
df_altitude
# Out:
#              time truck_name  truck_id  \
# 0      2021-11-17    abc-242       242
# 1      2021-11-17    abc-242       242
# 2      2021-11-17    abc-242       242
# 3      2021-11-17    abc-242       242
# 4      2021-01-04    abc-294       294
# ...           ...        ...       ...
# 95467  2021-02-15    abc-277       277
# 95468  2021-02-17    abc-277       277
# 95469  2021-02-17    abc-277       277
# 95470  2021-02-17    abc-277       277
# 95471  2021-02-17    abc-277       277
#
#                                          type  reading_id bin_num  final_val
# 0          Time(hours) at different Altitudes       86021   col_0   0.000000
# 1      Distance(miles) at different Altitudes       86021   col_0   0.000000
# 2          Time(hours) at different Altitudes       86021   col_0   0.000000
# 3      Distance(miles) at different Altitudes       86021   col_0   0.000000
# 4          Time(hours) at different Altitudes       86022   col_0   0.772778
# ...                                       ...         ...     ...        ...
# 95467  Distance(miles) at different Altitudes      130151   col_0   0.000000
# 95468      Time(hours) at different Altitudes      130152   col_0   0.000000
# 95469  Distance(miles) at different Altitudes      130152   col_0   0.000000
# 95470      Time(hours) at different Altitudes      130152   col_0   0.000000
# 95471  Distance(miles) at different Altitudes      130152   col_0   0.000000
#
# [95472 rows x 7 columns]

# %%
df_list = [df_engine_speed, df_altitude, df_inclination, df_wheel_based_speed]
df = pd.concat(df_list)

# %%
df = df.pivot_table(index=['time', 'truck_id'], columns='type',
                     values='final_val',aggfunc='mean').reset_index()

# %%
df['uuid'] = df.index.to_series().map(lambda x: uuid.uuid4())
df
# Out:
# type        time  truck_id  Distance(miles) at WheelBasedVehicleSpeed(mph)  \
# 0     2020-12-28       286                                   -1.898115e+06
# 1     2020-12-29       286                                   -1.808075e+06
# 2     2020-12-30       286                                   -1.600186e+06
# 3     2020-12-31       286                                   -1.647074e+06
# 4     2021-01-01       207                                    0.000000e+00
# ...          ...       ...                                             ...
# 4542  2022-01-08       294                                    6.114824e+04
# 4543  2022-01-08       296                                    3.134737e+05
# 4544  2022-01-09       208                                    8.796911e+05
# 4545  2022-01-09       209                                    0.000000e+00
# 4546  2022-01-09       296                                    3.304308e+05
#
# type  Distance(miles) at different Altitudes  \
# 0                              162463.500000
# 1                              144921.500000
# 2                              119689.500000
# 3                              148580.433333
# 4                                   0.000000
# ...                                      ...
# 4542                           599411.000000
# 4543                                0.000000
# 4544                                     NaN
# 4545                           135474.000000
# 4546                                0.000000
#
# type  Distance(miles) at different Engine Speeds (rpms)  \
# 0                                          6.202083e+05
# 1                                          1.091979e+06
# 2                                          1.805208e+05
# 3                                         -8.194444e+04
# 4                                          0.000000e+00
# ...                                                 ...
# 4542                                       2.362917e+06
# 4543                                       3.685158e+06
# 4544                                       8.310508e+06
# 4545                                       0.000000e+00
# 4546                                       3.334598e+06
#
# type  Distance(miles) at different RoadInclination(%)  \
# 0                                         1339.112903
# 1                                         -789.274194
# 2                                          587.849462
# 3                                         1372.231183
# 4                                            0.000000
# ...                                               ...
# 4542                                              NaN
# 4543                                      3947.306210
# 4544                                     16026.783871
# 4545                                         0.000000
# 4546                                      5371.034194
#
# type  Time(hours) at WheelBasedVehicleSpeed(mph)  \
# 0                                       1.792842
# 1                                       1.813446
# 2                                       1.383603
# 3                                       1.446769
# 4                                       3.031754
# ...                                          ...
# 4542                                    2.105701
# 4543                                    4.108464
# 4544                                   10.394748
# 4545                                    0.401286
# 4546                                    3.645029
#
# type  Time(hours) at different Altitudes  \
# 0                               1.815138
# 1                               1.781807
# 2                               1.565835
# 3                               1.470555
# 4                               0.001250
# ...                                  ...
# 4542                            0.858795
# 4543                            0.000000
# 4544                                 NaN
# 4545                            0.255278
# 4546                            0.000000
#
# type  Time(hours) at different Engine Speeds (rpms)  \
# 0                                         47.531875
# 1                                         48.625611
# 2                                         40.549742
# 3                                         37.285868
# 4                                         41.710093
# ...                                             ...
# 4542                                      45.623099
# 4543                                      53.315971
# 4544                                     108.892445
# 4545                                       5.520833
# 4546                                      40.695606
#
# type  Time(hours) at different RoadInclination(%)  \
# 0                                        0.000184
# 1                                       -0.002753
# 2                                        0.002549
# 3                                        0.002567
# 4                                       -0.019326
# ...                                           ...
# 4542                                          NaN
# 4543                                     0.050108
# 4544                                     0.309436
# 4545                                     0.029919
# 4546                                     0.062829
#
# type                                  uuid
# 0     baab0bec-2615-4510-afb9-ccf8dd66969f
# 1     f1019a50-2cc9-4fd5-8dca-9816ad785b6f
# 2     b056b8b2-2fd3-4ab1-a25d-7ccc3305213f
# 3     5e3fdb3d-bdb1-451d-808a-516ae6c95ec0
# 4     4b943527-2570-4c97-822d-b71ee7e5f247
# ...                                    ...
# 4542  8b0262f5-772d-4bf1-9526-b62c936b7140
# 4543  29a49321-68ea-4ac6-800d-903381e43f02
# 4544  204b2e72-ae61-4357-a080-fb4df9169a19
# 4545  ee6d5458-1c79-432f-bf20-b2189079e56b
# 4546  5ee0b903-cd42-4cbf-bb01-47f9fb0dbb04
#
# [4547 rows x 11 columns]

# %%
df.describe()
# Out:
# type      truck_id  Distance(miles) at WheelBasedVehicleSpeed(mph)  \
# count  4547.000000                                    4.547000e+03
# mean    258.192435                                    5.904024e+05
# std      35.043084                                    5.040838e+07
# min     201.000000                                   -1.471428e+09
# 25%     221.000000                                    3.858464e+04
# 50%     274.000000                                    2.365934e+05
# 75%     290.000000                                    5.951738e+05
# max     297.000000                                    2.286124e+09
#
# type   Distance(miles) at different Altitudes  \
# count                            3.543000e+03
# mean                             6.644728e+05
# std                              9.948156e+05
# min                              0.000000e+00
# 25%                              1.080975e+02
# 50%                              2.793622e+05
# 75%                              9.243595e+05
# max                              1.674670e+07
#
# type   Distance(miles) at different Engine Speeds (rpms)  \
# count                                       4.546000e+03
# mean                                       -1.007648e+07
# std                                         1.842733e+09
# min                                        -7.580179e+10
# 25%                                         7.202732e+05
# 50%                                         2.906849e+06
# 75%                                         6.748139e+06
# max                                         7.505267e+10
#
# type   Distance(miles) at different RoadInclination(%)  \
# count                                     3.697000e+03
# mean                                      9.042787e+04
# std                                       1.362355e+07
# min                                      -3.635681e+08
# 25%                                       6.297234e+02
# 50%                                       2.912236e+03
# 75%                                       6.342094e+03
# max                                       3.462059e+08
#
# type   Time(hours) at WheelBasedVehicleSpeed(mph)  \
# count                                 4547.000000
# mean                                     5.588392
# std                                      5.321105
# min                                      0.001823
# 25%                                      1.319545
# 50%                                      3.947383
# 75%                                      8.754609
# max                                     91.141168
#
# type   Time(hours) at different Altitudes  \
# count                         3543.000000
# mean                             1.133195
# std                              1.353892
# min                              0.000000
# 25%                              0.021667
# 50%                              0.612253
# 75%                              1.915750
# max                             13.541700
#
# type   Time(hours) at different Engine Speeds (rpms)  \
# count                                    4546.000000
# mean                                       62.053591
# std                                        61.083809
# min                                         0.000000
# 25%                                        15.944286
# 50%                                        44.037065
# 75%                                        99.027049
# max                                       958.674500
#
# type   Time(hours) at different RoadInclination(%)
# count                                  3697.000000
# mean                                      0.044946
# std                                       0.053123
# min                                      -0.280778
# 25%                                       0.006910
# 50%                                       0.032606
# 75%                                       0.069507
# max                                       0.611095

# %%
df['Distance(miles) at WheelBasedVehicleSpeed(mph)'] = abs(df['Distance(miles) at WheelBasedVehicleSpeed(mph)'])
df['Distance(miles) at different Engine Speeds (rpms)'] = abs(df['Distance(miles) at different Engine Speeds (rpms)'])
df['Time(hours) at different Engine Speeds (rpms)']= abs((df['Time(hours) at different Engine Speeds (rpms)']-df['Time(hours) at different Engine Speeds (rpms)'].min())/(df['Time(hours) at different Engine Speeds (rpms)'].max()-df['Time(hours) at different Engine Speeds (rpms)'].min()))
df['Time(hours) at different RoadInclination(%)'] = abs(df['Time(hours) at different RoadInclination(%)'])

# %%
l = []
for i in df[['uuid','time','Distance(miles) at different Altitudes','Distance(miles) at different Engine Speeds (rpms)','Distance(miles) at different RoadInclination(%)', 'Distance(miles) at WheelBasedVehicleSpeed(mph)','Time(hours) at different Altitudes', 'Time(hours) at different Engine Speeds (rpms)','Time(hours) at different RoadInclination(%)','Time(hours) at WheelBasedVehicleSpeed(mph)','truck_id']].columns:
    l.append(df[i].tolist())

# %%
query = """insert into newdata (ui , datel , distance_at_diff_altitude , distance_at_diff_engine_speeds , distance_at_diff_roadinclination , distance_at_wheelbased_vehicle_speed , time_at_diff_altitude , time_at_diff_engine_speeds , time_at_diff_roadinclination , time_at_wheelbased_vehicle_speed , truck_id)
values (?,?,?,?,?,?,?,?,?,?,?);"""
prepared = session2.prepare(query)
execute_concurrent_with_args(session2, prepared, zip(l[0],l[1],l[2],l[3],l[4],l[5],l[6],l[7],l[8],l[9],l[10]))
# Out:
# [ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01369dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0139db90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01369950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013bb750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f94d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01387dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ad050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ad290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01410710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0139ddd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01370710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01318710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01318050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013bb290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01369b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01318290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01370050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01377290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01318c10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01369050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01369710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013184d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f0750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01377090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013a6dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ad710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013bb090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013b54d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01318e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013704d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01370950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013a6050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01318950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013594d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01359090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01370290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013a6710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013b5950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01353310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0138e090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01370dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ade10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013cb2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01370b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013774d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013a6950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013adb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01410950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01359290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0137f710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013b5290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013b5dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013a6290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013b5750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01353090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ad990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013534d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01377dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01387b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01353710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01377950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01353dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0139d950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013b5b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013b5050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0139d710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013bb950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013a64d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013692d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0137f050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0137f4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013a6b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01353950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01353bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01359dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0137f290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013cb4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01395bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01359b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ad4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f04d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0137fbd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01410b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f0dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01359710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013874d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01359950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01395dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013d3990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013d3050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013da4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f0950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013d3b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01361050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ea950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01361510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01387990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013bb4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01361710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01361290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01361950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0138e290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f0050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01387710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01377b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0137f950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01387290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01387050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013da290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0137fdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013e2950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013e2710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01401710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013d3710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01410e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013694d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01377710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013e2290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013c4050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013d34d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013dab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01361b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013cb050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ea050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013da710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013bbdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01361dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013eae10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f9710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0138e4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0138e950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0138eb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013c4b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f9b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013eab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013cbbd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013d3290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013e2e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01395750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013952d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013c4950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013e2b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013954d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013bbb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0138e710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013da050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013c4e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013c44d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01395050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013e2050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01395950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0138edd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013cb950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013cb710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013c4710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013c4290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f9990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013d3e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0139d2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01418050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0139d4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0139d050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013cbdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013e24d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013da950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013dadd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f9dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ea710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01401e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01401950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f0b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ea510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f9290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f9050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013f0290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01401b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01409050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01401050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014012d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014014d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d013ea290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014094d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01410050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01418710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01418290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01409b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014184d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01418990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014104d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01418b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01418dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014102d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01409950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01409290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01409710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01421090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01409dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01421290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01427710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014214d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01436710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01427510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01427dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0142e4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01441510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0142e290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01427950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0142e950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01427bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01421b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01421710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01436b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014364d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01421dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0142eb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0142e050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01427290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01436dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01436090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01421950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0142edd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01427050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01436950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01436290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01446290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0142e710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01441710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01446050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01441950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01441050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01441290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01441e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01441b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01454710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0144db90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01454b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0144d290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014464d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0144ddd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01446750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014544d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01454050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01466990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0144d050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014542d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01466b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0146c710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01446950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01446b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01454950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0144d4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014664d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0145e4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0144d750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0145e290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0145e710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0144d950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0145e950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0146cb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014662d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01446dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0146c4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01466dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01454dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0145eb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0145ee10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01466050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0145e050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01474dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01466710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0146c2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0147b710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0146c990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0147b050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0146c050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01474950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0146cdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01474710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01474290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01485b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0148b050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0147b510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01485e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0148b950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01474b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01474050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0147bdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c0c950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0147b290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01474510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0149a050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01493710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a9dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b1290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01493e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0148bbd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a9050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a9290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0147bbd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01493950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014854d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a94d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0149a4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c0c050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0149a750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01485050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a9950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014932d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0149ab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0148b4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a2710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014934d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0148b2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0149a290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0149a950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a9750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0147b950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01493b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01485950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01485290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0148b710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0148bdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a9b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b1090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01485750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b1dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b1510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a22d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c04b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b94d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b9710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a24d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b1b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01493050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b1950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c0cb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b92d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a2950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b9050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc1050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a2dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014c1b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014c1050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014c1dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc1510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc1710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b9dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0149add0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b1710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc1290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014c1290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014c14d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014c1710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b9950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014c1990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a2050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014a2bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d014b9b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc7bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc7290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc7710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc7dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc7050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc1950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd1950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc1bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc1dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd14d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd1750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd1290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd1050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc74d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01be6290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bc7950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd1dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd1b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd8b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd84d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd8710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01be6050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bdf4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bdf290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bdf710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd8050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01be64d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bdfb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd8290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bdf090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01be6950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01be6710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd8990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01be6bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bdf950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bdfe10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c0ce10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01be6dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bd8dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bef290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bef950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bef050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bef4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c04dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bf7050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bf74d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bf7290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01befb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bf7710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bef750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bf7950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c1d2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c15b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01befdd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c0c4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c15950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bfd050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bfd290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bf7dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c04090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c0c710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bf7bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c15050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bfd710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c15dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c04290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c24dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c2c4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c044d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c04710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c24090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bfd950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c24950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bfdb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c1ddd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bfddd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c04950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c1d4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01bfd4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c0c290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c154d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c1d950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c1d050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c1d750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c1db90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c15710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c15290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c24510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c24290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c24bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c2c710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c2c950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c344d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c34050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c24710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c2ce10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c2cb90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c2c090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c34290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c34b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c2c290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c3b050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c34750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c3b710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c34950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c34dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c3b4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c3b950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c3b2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c43dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c4a4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01c434d0>),
# ...
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0200ed50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01ef5ad0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0200ef90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0201f610>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02017610>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02028490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020171d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02004d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02004b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0201f410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02017bd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0201f210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0201fe10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0201f650>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02028050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020173d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0200ef50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0208e310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0201f1d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02028410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02017dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02028a10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02028450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02017b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02039e90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02041ad0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02031090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02039ad0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02041b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02028c10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02039ed0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02028e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01efd510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02031290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020312d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02041110>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0208e790>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02031890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02031ad0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02031850>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02041510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02039310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02039290>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020392d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02039090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020398d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0208e550>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02031a90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049110>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02041550>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02041b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02041310>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049150>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049350>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0205abd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02052590>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02063410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02052d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02052390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0205afd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020525d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049d10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020d1150>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0205a790>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02052b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020d1d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02052f90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0205a210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02052350>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0205add0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02049d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02063210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02063850>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0205a1d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02039890>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02052b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207b4d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207b910>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02063610>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207b6d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0205a990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020d1750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02063810>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020d1d50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02074e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020746d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02074490>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207bf10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02063e50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d01ed1f90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02074c50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02063e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0206da50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0206d410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207b8d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0205ab90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020d1710>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0206d650>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0206d850>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0206de50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0206de90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02074450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02074e90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207b0d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207b2d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0208e750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02095990>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02063dd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0209d1d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0206dc50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0209dbd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02084d10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0209d5d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020844d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0208ed90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02084750>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0209d7d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207be90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0209d9d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020a7210>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020a7850>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0207bed0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02095f90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02084510>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02084b10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02095b90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0208ed10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02095d90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0209d3d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b2a90>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02095350>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020a7e10>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020a7610>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020d1b50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0208ed50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b2050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020d1950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0209ddd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b2250>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d0209dfd0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020a7410>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02095950>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d02095390>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b9050>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b90d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020953d0>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b2a50>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b9650>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b9090>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020a7810>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b2450>),
#  ExecutionResult(success=True, result_or_exc=<cassandra.cluster.ResultSet object at 0x7f8d020b2650>),
#  ...]

# %%
query = "select * from iac689.data_1;"
df = pd.DataFrame(list(session1.execute(query)))
df
# Out:
#                                        uid        active  reading_id  \
# 0     1b644c6e-7f03-11ec-99b7-acde48001122   5400.000000      103995
# 1     1ba064e2-7f03-11ec-99b7-acde48001122   7340.000000      103997
# 2     d847cb7c-7f02-11ec-99b7-acde48001122  11815.000000      103358
# 3     6a9d1424-7f02-11ec-99b7-acde48001122      0.021667       99698
# 4     f6d2f940-7f02-11ec-99b7-acde48001122      0.138056      103646
# ...                                    ...           ...         ...
# 8525  eb7bfd62-7f02-11ec-99b7-acde48001122      0.000000      103539
# 8526  fe85cb18-7f02-11ec-99b7-acde48001122      0.115278      103720
# 8527  17da6c18-7f03-11ec-99b7-acde48001122      0.254722      103961
# 8528  5300048e-7f02-11ec-99b7-acde48001122      0.130556       86044
# 8529  239fc9da-7f03-11ec-99b7-acde48001122      0.356944      104072
#
#       start_mileage  start_time  truck_id truck_name  \
# 0        15906600.0  2021-02-19       205    abc-205
# 1        15912000.0  2021-02-19       205    abc-205
# 2        12433600.0  2021-01-13       205    abc-205
# 3        17789500.0  2021-01-11       284    abc-284
# 4        14102000.0  2021-02-01       205    abc-205
# ...             ...         ...       ...        ...
# 8525     13469200.0  2021-01-25       205    abc-205
# 8526     14719100.0  2021-02-05       205    abc-205
# 8527     15560800.0  2021-02-16       205    abc-205
# 8528      8068540.0  2021-02-15       294    abc-294
# 8529     16133600.0  2021-02-23       205    abc-205
#
#                                 type
# 0     Distance(miles) with CC active
# 1     Distance(miles) with CC active
# 2     Distance(miles) with CC active
# 3         Time(hours) with CC Active
# 4         Time(hours) with CC Active
# ...                              ...
# 8525  Distance(miles) with CC active
# 8526      Time(hours) with CC Active
# 8527      Time(hours) with CC Active
# 8528      Time(hours) with CC Active
# 8529      Time(hours) with CC Active
#
# [8530 rows x 8 columns]

# %%
query = "select * from iac689.data_2;"
df = pd.DataFrame(list(session2.execute(query)))
df
# Out:
#                                         ui       datel  \
# 0     1c9a40f7-28bd-448b-837f-7e6f26867cee  2021-01-12
# 1     eed85ca4-db7c-42a3-b4f6-46660ac6f5ab  2021-10-01
# 2     69b49f87-6525-4203-8168-a406da377443  2021-11-18
# 3     375516c0-521f-4411-b83a-74f84ab454be  2021-05-12
# 4     3f15f13f-62e0-435a-910b-317c3fda47ac  2021-01-25
# ...                                    ...         ...
# 4542  2d46a503-3581-40eb-9ad9-124e7a362185  2021-07-27
# 4543  9932ae23-5a33-42f1-9a87-ec803a18c325  2021-08-06
# 4544  c0b4c700-96ab-438e-a272-e45ba97a3974  2021-06-03
# 4545  e29ed179-f997-429f-b592-8158bd7b2030  2021-10-11
# 4546  06d041b4-eef0-4474-ae48-7b80d50ec25d  2021-04-08
#
#       distance_at_diff_altitude  distance_at_diff_engine_speeds  \
# 0                  2.468247e+05                    7.139896e+05
# 1                  0.000000e+00                    1.087964e+07
# 2                           NaN                    1.010224e+07
# 3                  5.921890e+05                    5.071094e+05
# 4                           NaN                    2.643425e+07
# ...                         ...                             ...
# 4542               5.230573e+05                    8.439053e+05
# 4543               8.052310e+05                    8.942562e+05
# 4544               2.373810e+06                    2.268493e+05
# 4545                        NaN                    5.238979e+06
# 4546                        NaN                    5.120176e+06
#
#       distance_at_diff_roadinclination  distance_at_wheelbased_vehicle_speed  \
# 0                         5.578044e+05                          9.648508e+05
# 1                         8.499720e+06                          1.470222e+07
# 2                         7.892374e+06                          1.365167e+07
# 3                                  NaN                          6.852830e+05
# 4                         2.065176e+07                          3.572196e+07
# ...                                ...                                   ...
# 4542                               NaN                          1.140412e+06
# 4543                               NaN                          1.208454e+06
# 4544                               NaN                          3.065532e+05
# 4545                      4.092952e+06                          7.079684e+06
# 4546                      4.000138e+06                          6.919157e+06
#
#       time_at_diff_altitude  time_at_diff_engine_speeds  \
# 0                  0.318268                7.137108e+05
# 1                  0.000000                1.087643e+07
# 2                       NaN                1.010193e+07
# 3                  1.227917                5.051501e+05
# 4                       NaN                2.643222e+07
# ...                     ...                         ...
# 4542               0.531806                8.434997e+05
# 4543               4.340280                8.896362e+05
# 4544               2.066203                2.259348e+05
# 4545                    NaN                5.232000e+06
# 4546                    NaN                5.112247e+06
#
#       time_at_diff_roadinclination  time_at_wheelbased_vehicle_speed  truck_id
# 0                     5.575866e+05                      9.644741e+05       284
# 1                     8.497214e+06                      1.469788e+07       296
# 2                     7.892130e+06                      1.365125e+07       282
# 3                              NaN                      6.826352e+05       294
# 4                     2.065017e+07                      3.571922e+07       279
# ...                            ...                               ...       ...
# 4542                           NaN                      1.139864e+06       205
# 4543                           NaN                      1.202211e+06       294
# 4544                           NaN                      3.053172e+05       292
# 4545                  4.087500e+06                      7.070270e+06       208
# 4546                  3.993943e+06                      6.908442e+06       277
#
# [4547 rows x 11 columns]
